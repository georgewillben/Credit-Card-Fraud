# %% [markdown]
# # Random Forest Modeling

# %% [markdown]
# ## Objectives
# * Load data
# * Tune hyper parameters for each version of the data
# * Select a model
# * Examine results
# * Save results

# %% [markdown]
# #### Load data

# %% [markdown]
# I will start by importing the necessary libraries.

# %%
import pickle # loading data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE # RFE
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import NearMiss
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, recall_score, precision_score, f1_score, accuracy_score, roc_curve, auc, precision_recall_curve, confusion_matrix
from sklearn.model_selection import GridSearchCV
import time
from modeling_functions import *

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Pickle

# %%
# Load data
pickle_in = open("olr_keys_n_components.pickle", "rb")
olr_keys_n_components = list(pickle.load(pickle_in))
pickle_in.close()

# Sanity Check
print(olr_keys_n_components)
# Out:
# [('s1_r1_o1', 16), ('s1_r1_o3', 16), ('s1_r2_o1', 16), ('s1_r2_o3', 15), ('s2_r1_o1', 24), ('s2_r1_o3', 25), ('s2_r2_o1', 19), ('s2_r2_o3', 20), ('s3_r1_o1', 23), ('s3_r1_o3', 24), ('s3_r2_o1', 19), ('s3_r2_o3', 18), ('s4_r1_o1', 21), ('s4_r1_o3', 22), ('s4_r2_o1', 16), ('s4_r2_o3', 18)]

# %%
# Load data
pickle_in = open("../clean_data.pickle", "rb")
df = pickle.load(pickle_in)
pickle_in.close()

# Seperate X and y
X = df.drop('Class', axis=1)
y = df.Class

df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Tune hyperparameters

# %% [markdown]
# My goal for this project is to create a model that can help alert a credit lender to suspicious activity. <br><br>
#
# For this reason I want to have low false negatives, so I will be using recall as my main metric. High recall will mean a low amount of fradulent transactions are left undetected. <br><br>
#
# My second metric will be precision because I do not want false positives either. low precision would cause the model to flag too large an amount of the data as likely to be fraudulent. If the credit lender chose to take preventative action on say, every other transaction, then that would be a nuisance to both the credit lender and the clients. <br><br>
#
# However precision does not need to be nearly as high as recall. If recall was say %80 then I would have potentially stopped %80 percent of fraud and if precision was say %20 then less than 1 out of 100 transactions would be flagged as suspicous to fraud, because in this dataset fraud accounts for %0.17 percent of the data I was  given. <br><br>
#
# F1-score is the harmonic mean of recall and precision. It is not the best metric to use though because it is important that recall is high, but precision can get away with being much lower.<br><br>
#
# The metrics mentioned above are calculated by comparing the known values to the model's predicted values. The simplified formulas for precision and recall are showed below.
# <img src="../Images/Precision_Recall.png"><br>
# Image Source: https://towardsdatascience.com/accuracy-precision-recall-or-f1-331fb37c5cb9
# <br><br>

# %% [markdown]
# To tune the hyperparameters I will use my own function called customGridSearch. It has a doc string attached. The function will go through the data transforming it according to the function's parameters and return the cross validation scores for each method as well as for each combination of parameters.

# %% [markdown]
# The parameter grid in the cell below was taken from the <a href=https://www.kaggle.com/janiobachmann/credit-fraud-dealing-with-imbalanced-datasets>top rated kaggle post</a> I marked the url as source 1.

# %% [markdown]
# ## Random Forest Classifier

# %%
# Instantiate logistic regression classifer
clf = RandomForestClassifier

# Create parameter grid (Source 1)
params = {
    "criterion": ["gini", "entropy"], 
    "max_depth": list(range(2,4,1)), 
    "min_samples_leaf": list(range(5,7,1)),
    "n_estimators": [10]
}

# %% [markdown]
# Warning the following cell 5 took minutes to run!

# %%
# Tune hyperparameters for all scalers 
# Implementing NearMiss
# No outliers removed
# No PCA

t1 = time.time()

# Record results
results_o1 = {}
for scaler_str in ['s1', 's2', 's3', 's4']:
    print(scaler_str, '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    results_o1[scaler_str] = customGridSearchCV(clf, params, X, y, 'manual', scaler_str, NearMiss())
    
t2 = time.time()

print((t2 - t1)/60)
# Out:
# s1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.8561907065494907
#  precision: 0.016915973345694387
#  f1-score: 0.032962233790608676
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.8499019054529819
#  precision: 0.049176798505088354
#  f1-score: 0.09141070307340372
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.8815340374640543
#  precision: 0.009597594792957619
#  f1-score: 0.018971067884175744
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9027923351877233
#  precision: 0.004862972609499556
#  f1-score: 0.009672825225653173
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.8413824612324975
#  precision: 0.01162661841576189
#  f1-score: 0.022884592558373048
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.8477115751565482
#  precision: 0.020052815934282195
#  f1-score: 0.03901609253232745
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9006691929371926
#  precision: 0.006620818129667412
#  f1-score: 0.013140448586579057
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.8689026848343143
#  precision: 0.006418792343380807
#  f1-score: 0.012741673717375885
#
# s2 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9386707516998576
#  precision: 0.002531516444848315
#  f1-score: 0.00504912843137767
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.953532747453573
#  precision: 0.0026133484442912047
#  f1-score: 0.005212093506511872
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9725469644440862
#  precision: 0.0022028296510397008
#  f1-score: 0.004395073397940348
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9683275551613857
#  precision: 0.002103233862424218
#  f1-score: 0.004197119905282075
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9449998656239081
#  precision: 0.0032269500960925637
#  f1-score: 0.006429969429046477
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9408610819962911
#  precision: 0.002821905861476908
#  f1-score: 0.005623092525261185
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9725469644440862
#  precision: 0.0021679337869457325
#  f1-score: 0.004325961044600892
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9767932489451477
#  precision: 0.002290004506671923
#  f1-score: 0.00456912135618
#
# s3 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.974670106694617
#  precision: 0.002259793953506668
#  f1-score: 0.004508720927698815
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9619715660189739
#  precision: 0.0022071644677959332
#  f1-score: 0.004403840026549529
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9767932489451477
#  precision: 0.0020741205369346765
#  f1-score: 0.004139397294906309
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9767663737267865
#  precision: 0.0020335319129678483
#  f1-score: 0.004058488925747547
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9599021742051654
#  precision: 0.0021466159043621617
#  f1-score: 0.004283389282841196
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9492864629525114
#  precision: 0.0022964258806148826
#  f1-score: 0.004581728211300601
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9788895159773174
#  precision: 0.001886696059347653
#  f1-score: 0.0037660294190637374
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9599021742051654
#  precision: 0.002001575039006395
#  f1-score: 0.003994719075164269
#
# s4 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9028192104060846
#  precision: 0.003905809207572452
#  f1-score: 0.007774048046738245
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9070789325163267
#  precision: 0.003919543165171848
#  f1-score: 0.00779842584297421
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9133946088311967
#  precision: 0.0035564998981612527
#  f1-score: 0.007078765201313352
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.936668547931952
#  precision: 0.002655764696908035
#  f1-score: 0.00529545940988902
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9028595232336262
#  precision: 0.003943632617746982
#  f1-score: 0.007851400695691796
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.894366954231503
#  precision: 0.005241867492366887
#  f1-score: 0.010407445201874243
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9154908758633663
#  precision: 0.0030735939298331062
#  f1-score: 0.006124656347465296
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9472036335295225
#  precision: 0.0029762507456148717
#  f1-score: 0.0059326657804931225
#
# 4.669052958488464

# %% [markdown]
# Warning: The following cell took 4 minutes to run!

# %%
# Tune hyperparameters for all scalers 
# Implementing NearMiss
# outliers removed
# No PCA

t1 = time.time()

# Record results
results_o3 = {}
for scaler_str in ['s1', 's2', 's3', 's4']:
    print(scaler_str, '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    results_o3[scaler_str] = customGridSearchCV(clf, params, X, y, 'manual', scaler_str, NearMiss(), outlier_removal=True)
    
t2 = time.time()

print((t2 - t1)/60)
# Out:
# s1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.8561772689403101
#  precision: 0.02601376317503507
#  f1-score: 0.05005798171249858
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.8435056034830284
#  precision: 0.06595397360835854
#  f1-score: 0.1130338080678706
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.862533258082722
#  precision: 0.012803445284855913
#  f1-score: 0.025180689502753442
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9048886022198931
#  precision: 0.005823538874727411
#  f1-score: 0.011571296273044929
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.8604369910505523
#  precision: 0.013780363849539562
#  f1-score: 0.02712611895028498
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.8435324787013895
#  precision: 0.02192590265852327
#  f1-score: 0.04259431541457598
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.8794377704318848
#  precision: 0.011922361266660672
#  f1-score: 0.023443508961637244
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.8815071622456933
#  precision: 0.011444155659237324
#  f1-score: 0.022516961203522663
#
# s2 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.938751377354941
#  precision: 0.0028689065458038002
#  f1-score: 0.005718527525516166
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.928108790883926
#  precision: 0.0027077398312297697
#  f1-score: 0.005398914521251383
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9513961675938617
#  precision: 0.002243970875183826
#  f1-score: 0.004477365781936991
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9492730253433308
#  precision: 0.002511407168272166
#  f1-score: 0.005009513921162033
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9725200892257249
#  precision: 0.0024044747438749466
#  f1-score: 0.004796922839502733
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9640678330511436
#  precision: 0.0029722464287856034
#  f1-score: 0.005925132892523285
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9662044129108548
#  precision: 0.0021231587632573328
#  f1-score: 0.004236631003052876
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9767798113359673
#  precision: 0.002037077051156962
#  f1-score: 0.0040654396870484465
#
# s3 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9493267757800532
#  precision: 0.0026000496387228234
#  f1-score: 0.005185024022578771
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9408745196054719
#  precision: 0.0023754817560993706
#  f1-score: 0.004738806338547077
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9640947082695046
#  precision: 0.0021174469942980127
#  f1-score: 0.004225481061111998
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9810126582278481
#  precision: 0.002195003013169479
#  f1-score: 0.004380040996206312
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9513692923755005
#  precision: 0.002322331215690601
#  f1-score: 0.004632951013148075
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9577521567362735
#  precision: 0.002212207325399426
#  f1-score: 0.0044139956691369555
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9746835443037974
#  precision: 0.0020417601864757278
#  f1-score: 0.004074653660475969
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9704641350210971
#  precision: 0.0019939258195339235
#  f1-score: 0.003979504986698027
#
# s4 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.8816684135558601
#  precision: 0.013120964631257554
#  f1-score: 0.02573338143397337
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9112983417990271
#  precision: 0.0035693851514283725
#  f1-score: 0.0071085442971468285
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9324088258217098
#  precision: 0.0026379734021709247
#  f1-score: 0.005259149339116175
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9303663092262625
#  precision: 0.003018488457364415
#  f1-score: 0.006013760981094595
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9027520223601817
#  precision: 0.004581039640537935
#  f1-score: 0.00910457331352118
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.8964363460453116
#  precision: 0.005745911217107058
#  f1-score: 0.011402578636165278
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9281894165390093
#  precision: 0.003306217759887672
#  f1-score: 0.006583925542541102
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9218871778333199
#  precision: 0.0031036713173822027
#  f1-score: 0.006183652847208816
#
# 4.773534687360128

# %% [markdown]
# Warning: The following cell took 8 minutes to run!

# %%
# Tune hyperparameters for all scalers 
# Implementing NearMiss
# No outliers removed
# PCA

t1 = time.time()


# Get correct scaler_str's and n_components
o1_n_components = []
for key, n in olr_keys_n_components:
    if 'r2_o1' in key:
        o1_n_components.append(n)
        

# Record results
results_o1_p = {}
for scaler_str, n in zip(['s1', 's2', 's3', 's4'], o1_n_components):
    print(scaler_str, '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    results_o1_p[scaler_str] = customGridSearchCV(clf, params, X, y, 'manual', scaler_str, NearMiss(), pca=PCA(n))
    
t2 = time.time()

print((t2 - t1)/60)
# Out:
# s1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9384557499529684
#  precision: 0.004249756052705766
#  f1-score: 0.008428428054906135
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9174393291945497
#  precision: 0.006532853451885703
#  f1-score: 0.012898250701960545
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.989384288747346
#  precision: 0.0023763715960965046
#  f1-score: 0.004740177399083042
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9809589077911257
#  precision: 0.0026952272123693575
#  f1-score: 0.005374446286262067
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9575371549893843
#  precision: 0.003372731599676626
#  f1-score: 0.006709068290510367
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9320594479830149
#  precision: 0.006231967168652388
#  f1-score: 0.012275201776726622
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.951167728237792
#  precision: 0.003230641926221025
#  f1-score: 0.0064279924089573
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9300169313875676
#  precision: 0.008175992977549926
#  f1-score: 0.016014165476154033
#
# s2 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9408207691687496
#  precision: 0.002123640791712213
#  f1-score: 0.004236647207524976
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9217393641323337
#  precision: 0.002272366826277969
#  f1-score: 0.004531491772847188
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9682738047246634
#  precision: 0.0018306860025144752
#  f1-score: 0.003654335277196092
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9534924346260313
#  precision: 0.001886908955702075
#  f1-score: 0.003766104950059865
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9386304388723158
#  precision: 0.0016556220747025007
#  f1-score: 0.00330540617917373
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.959821548550082
#  precision: 0.002652717531997447
#  f1-score: 0.00528664437165258
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9555752640490205
#  precision: 0.0018634845710803918
#  f1-score: 0.0037194670812936985
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9576984062995512
#  precision: 0.001945041612182977
#  f1-score: 0.0038818020171482825
#
# s3 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.936668547931952
#  precision: 0.003144564818523675
#  f1-score: 0.006264514419170218
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9429439114192802
#  precision: 0.002866525714793363
#  f1-score: 0.00571471945175529
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9725604020532668
#  precision: 0.001830508309799685
#  f1-score: 0.0036540263382482583
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9641215834878659
#  precision: 0.0022094476093856468
#  f1-score: 0.00440808820404219
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9303394340079013
#  precision: 0.00238702631530732
#  f1-score: 0.004761280717358555
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9345454056814212
#  precision: 0.0022250779338125796
#  f1-score: 0.004439334337898406
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9683141175522051
#  precision: 0.0020084924781175848
#  f1-score: 0.00400844547846005
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9767932489451477
#  precision: 0.0020348272670891445
#  f1-score: 0.004061022633900084
#
# s4 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9303125587895401
#  precision: 0.004978335471227725
#  f1-score: 0.009897391253303313
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9451073664973529
#  precision: 0.004777198821285723
#  f1-score: 0.009490293605847988
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9345454056814212
#  precision: 0.003791394785213597
#  f1-score: 0.007550861851145615
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9450939288881722
#  precision: 0.003616895103021126
#  f1-score: 0.0072036319954770335
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9154774382541858
#  precision: 0.003852427350907959
#  f1-score: 0.007671517678421109
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9324088258217098
#  precision: 0.005630901615205735
#  f1-score: 0.011190341527849432
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9556424520949233
#  precision: 0.002511318426680493
#  f1-score: 0.005007995231312409
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9472305087478836
#  precision: 0.003910941868677261
#  f1-score: 0.007777547028682819
#
# 4.7895641644795734

# %% [markdown]
# Warning: this cell took 8 minutes to run!

# %%
# Tune hyperparameters for all scalers 
# Implementing NearMiss
# Outliers removed
# PCA

t1 = time.time()


# Get correct scaler_str's and n_components
o3_n_components = []
for key, n in olr_keys_n_components:
    if 'r2_o3' in key:
        o3_n_components.append(n)
        

# Record results
results_o1_p = {}
for scaler_str, n in zip(['s1', 's2', 's3', 's4'], o3_n_components):
    print(scaler_str, '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    results_o1_p[scaler_str] = customGridSearchCV(clf, params, X, y, 'manual', scaler_str, NearMiss(), 
                                                  outlier_removal=True, pca=PCA(n))
    
t2 = time.time()

print((t2 - t1)/60)
# Out:
# s1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9341825902335458
#  precision: 0.004526528092221553
#  f1-score: 0.008967910927366795
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9023354564755839
#  precision: 0.0017670278530406327
#  f1-score: 0.003526910858629473
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9640409578327823
#  precision: 0.002040012260141031
#  f1-score: 0.004071171383196943
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9662178505200355
#  precision: 0.0024267426572209196
#  f1-score: 0.004839714238909065
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9237684431186004
#  precision: 0.0024170237276189797
#  f1-score: 0.004820351644035101
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9214437367303608
#  precision: 0.0029719856148467273
#  f1-score: 0.005916505136288212
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 1.0
#  precision: 0.0017609103343863557
#  f1-score: 0.003515626048661459
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9660565992098685
#  precision: 0.0020618594480874743
#  f1-score: 0.004114446870584867
#
# s2 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9492999005616921
#  precision: 0.001668750867102378
#  f1-score: 0.003331639201327573
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9239565696471285
#  precision: 0.0025119669331768245
#  f1-score: 0.005008230222309705
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9767798113359673
#  precision: 0.0017064578467694616
#  f1-score: 0.0034069521162746427
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9703969469751943
#  precision: 0.0017343124384355845
#  f1-score: 0.003462432580941108
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9767663737267865
#  precision: 0.0017459125823126925
#  f1-score: 0.0034855833214684994
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9429707866376414
#  precision: 0.0016759170330508798
#  f1-score: 0.003345885442233279
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9767394985084255
#  precision: 0.0017477335445352938
#  f1-score: 0.003489212615316027
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9704103845843748
#  precision: 0.0019860549763130605
#  f1-score: 0.003963785824974629
#
# s3 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9492730253433308
#  precision: 0.002387524091858413
#  f1-score: 0.004762738251049566
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9514364804214034
#  precision: 0.0026447042356825454
#  f1-score: 0.00527400040050642
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9767663737267865
#  precision: 0.0018400176972120845
#  f1-score: 0.003673029867503102
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9767932489451477
#  precision: 0.0020558572009167554
#  f1-score: 0.004102601290318697
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9661775376924938
#  precision: 0.0019724303610430833
#  f1-score: 0.003936639041207588
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9767663737267865
#  precision: 0.0020783055202285043
#  f1-score: 0.004147720723678837
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9810126582278481
#  precision: 0.0019466955912041588
#  f1-score: 0.0038856105600286023
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9725604020532668
#  precision: 0.0019209221164605886
#  f1-score: 0.0038341431001963806
#
# s4 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.923970007256309
#  precision: 0.005465394190386033
#  f1-score: 0.010865263602109055
#
#
#  {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9302991211803596
#  precision: 0.004249071226928624
#  f1-score: 0.00845262419329545
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9408745196054719
#  precision: 0.004097739152237697
#  f1-score: 0.008157026808029174
#
#
#  {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9408610819962911
#  precision: 0.0023833266310160574
#  f1-score: 0.004754607020859856
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9365879222768685
#  precision: 0.002718511140745991
#  f1-score: 0.005417908233673281
#
#
#  {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9387916901824828
#  precision: 0.0034421086793610263
#  f1-score: 0.006852796303555055
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 5, 'n_estimators': 10}
#  recall 0.9429707866376414
#  precision: 0.0023176418439215026
#  f1-score: 0.004623130475816593
#
#
#  {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 6, 'n_estimators': 10}
#  recall 0.9324357010400709
#  precision: 0.0034392334185534036
#  f1-score: 0.006848729710568518
#
# 4.789970135688781

# %% [markdown]
# # Model selection

# %% [markdown]
# Now I will look through each models scores manually and conclude which one is the best performing model.

# %% [markdown]
# My choice a model using the data scaled with StandardScaler, with the outliers removed and with PCA because it had a high cross validated recall of ~%93, but it had a super low precision of ~%1
# The models parameters are as follows: <br> <br>
# criterion: 'gini' <br>
# max_depth: 3<br>
# min_samples_leaf: 6<br>
# n_estimators: 10

# %% [markdown]
# ##### Final Model

# %% [markdown]
# Now I will check the scores at each split of the model to make sure it is not over fitting.

# %%
# Best model
# Print cross val scores
for key, n in olr_keys_n_components:
    if key == 's1_r2_o1':
        n_components = n

model = RandomForestClassifier(criterion='entropy', max_depth=3, min_samples_leaf=6, n_estimators=10)
customCV(model, X, y, 's1', NearMiss(), outlier_removal=True,
         pca=PCA(n_components), print_splits=True)
# Out:
# split 1
# recall: 1.0
# precision: 0.0017
# f1: 0.0035
# split 2
# recall: 0.943
# precision: 0.0029
# f1: 0.0058
# split 3
# recall: 0.8917
# precision: 0.0036
# f1: 0.0072
# Mean Scores:
# Mean recall: 0.9449
# Mean precision: 0.0027
# Mean f1: 0.0055
# [0.9449192399688249, 0.0027484282851757955, 0.005479248226513808]

# %% [markdown]
# #### Save Data

# %% [markdown]
# Now I will save the data along with a string to represent the transformations done to the data

# %%
pickle_out = open("Models/RandomForest.pickle", "wb")
pickle.dump([model, 's1_r2_o1, pca'+str(n_components)], pickle_out)
pickle_out.close()

# %% [markdown]
# ## Sources
# 1) Top rated kaggle post: https://www.kaggle.com/janiobachmann/credit-fraud-dealing-with-imbalanced-datasets
